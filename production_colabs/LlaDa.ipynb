# %%
# In the same venv as your notebook/kernel
# !pip uninstall -y torch torchvision torchaudio

# !pip install torch==2.5.0 torchvision==0.20.1 torchaudio==2.5.1
# Out:
# WARNING: Skipping torch as it is not installed.
# WARNING: Skipping torchvision as it is not installed.
# WARNING: Skipping torchaudio as it is not installed.
# ERROR: Could not find a version that satisfies the requirement torch==2.5.0 (from versions: 2.6.0, 2.7.0, 2.7.1, 2.8.0, 2.9.0, 2.9.1, 2.10.0)
# ERROR: No matching distribution found for torch==2.5.0

# %%
# !pip install --upgrade transformers==4.46.2 torch==2.6.0 accelerate safetensors
# Out:
# Requirement already satisfied: transformers==4.46.2 in /Users/davidbong/Documents/GPU_Labs/.venv/lib/python3.13/site-packages (4.46.2)
# Collecting torch==2.6.0
#   Using cached torch-2.6.0-cp313-none-macosx_11_0_arm64.whl.metadata (28 kB)
# Requirement already satisfied: accelerate in /Users/davidbong/Documents/GPU_Labs/.venv/lib/python3.13/site-packages (1.12.0)
# Requirement already satisfied: safetensors in /Users/davidbong/Documents/GPU_Labs/.venv/lib/python3.13/site-packages (0.7.0)
# Requirement already satisfied: filelock in /Users/davidbong/Documents/GPU_Labs/.venv/lib/python3.13/site-packages (from transformers==4.46.2) (3.20.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /Users/davidbong/Documents/GPU_Labs/.venv/lib/python3.13/site-packages (from transformers==4.46.2) (0.36.2)
# Requirement already satisfied: numpy>=1.17 in /Users/davidbong/Documents/GPU_Labs/.venv/lib/python3.13/site-packages (from transformers==4.46.2) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in /Users/davidbong/Documents/GPU_Labs/.venv/lib/python3.13/site-packages (from transformers==4.46.2) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/davidbong/Documents/GPU_Labs/.venv/lib/python3.13/site-packages (from transformers==4.46.2) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/davidbong/Documents/GPU_Labs/.venv/lib/python3.13/site-packages (from transformers==4.46.2) (2026.1.15)
# Requirement already satisfied: requests in /Users/davidbong/Documents/GPU_Labs/.venv/lib/python3.13/site-packages (from transformers==4.46.2) (2.32.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /Users/davidbong/Documents/GPU_Labs/.venv/lib/python3.13/site-packages (from transformers==4.46.2) (0.20.3)
# Requirement already satisfied: tqdm>=4.27 in /Users/davidbong/Documents/GPU_Labs/.venv/lib/python3.13/site-packages (from transformers==4.46.2) (4.67.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/davidbong/Documents/GPU_Labs/.venv/lib/python3.13/site-packages (from torch==2.6.0) (4.15.0)
# Requirement already satisfied: networkx in /Users/davidbong/Documents/GPU_Labs/.venv/lib/python3.13/site-packages (from torch==2.6.0) (3.6.1)
# Requirement already satisfied: jinja2 in /Users/davidbong/Documents/GPU_Labs/.venv/lib/python3.13/site-packages (from torch==2.6.0) (3.1.6)
# Requirement already satisfied: fsspec in /Users/davidbong/Documents/GPU_Labs/.venv/lib/python3.13/site-packages (from torch==2.6.0) (2025.10.0)
# Requirement already satisfied: setuptools in /Users/davidbong/Documents/GPU_Labs/.venv/lib/python3.13/site-packages (from torch==2.6.0) (77.0.3)
# Collecting sympy==1.13.1 (from torch==2.6.0)
#   Using cached sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/davidbong/Documents/GPU_Labs/.venv/lib/python3.13/site-packages (from sympy==1.13.1->torch==2.6.0) (1.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/davidbong/Documents/GPU_Labs/.venv/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.46.2) (1.2.0)
# Requirement already satisfied: psutil in /Users/davidbong/Documents/GPU_Labs/.venv/lib/python3.13/site-packages (from accelerate) (7.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/davidbong/Documents/GPU_Labs/.venv/lib/python3.13/site-packages (from jinja2->torch==2.6.0) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/davidbong/Documents/GPU_Labs/.venv/lib/python3.13/site-packages (from requests->transformers==4.46.2) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/davidbong/Documents/GPU_Labs/.venv/lib/python3.13/site-packages (from requests->transformers==4.46.2) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/davidbong/Documents/GPU_Labs/.venv/lib/python3.13/site-packages (from requests->transformers==4.46.2) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/davidbong/Documents/GPU_Labs/.venv/lib/python3.13/site-packages (from requests->transformers==4.46.2) (2026.1.4)
# Using cached torch-2.6.0-cp313-none-macosx_11_0_arm64.whl (66.5 MB)
# Using cached sympy-1.13.1-py3-none-any.whl (6.2 MB)
# Installing collected packages: sympy, torch
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.14.0
#     Uninstalling sympy-1.14.0:
#       Successfully uninstalled sympy-1.14.0━━━━━ 0/2 [sympy]
#   Attempting uninstall: torch━━━━━━━━━━━━━━━━━━━ 0/2 [sympy]
#     Found existing installation: torch 2.11.0.dev20260208 [sympy]
#     Uninstalling torch-2.11.0.dev20260208:━━━━━━━━━━━━━━━━━━━ 1/2 [torch]
#       Successfully uninstalled torch-2.11.0.dev20260208━━━━━━━ 1/2 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [torch]32m1/2 [torch]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# vllm 0.14.1 requires tokenizers>=0.21.1, but you have tokenizers 0.20.3 which is incompatible.
# vllm 0.14.1 requires torch==2.9.1; platform_system == "Darwin" or platform_machine == "ppc64le" or platform_machine == "aarch64", but you have torch 2.6.0 which is incompatible.
# vllm 0.14.1 requires transformers<5,>=4.56.0, but you have transformers 4.46.2 which is incompatible.
# torchaudio 2.10.0 requires torch==2.10.0, but you have torch 2.6.0 which is incompatible.
# torchvision 0.26.0.dev20260208 requires torch==2.11.0.dev20260208, but you have torch 2.6.0 which is incompatible.
# Successfully installed sympy-1.13.1 torch-2.6.0

# %%
import torch
from transformers import AutoModel, AutoTokenizer
import os
model_path = "Dream-org/Dream-v0-Instruct-7B"
model = AutoModel.from_pretrained(model_path, torch_dtype=torch.bfloat16, trust_remote_code=True)
tokenizer = AutoTokenizer.from_pretrained(model_path, trust_remote_code=True)
model = model.to("mps").eval()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 5
#       3 import os
#       4 model_path = "Dream-org/Dream-v0-Instruct-7B"
# ----> 5 model = AutoModel.from_pretrained(model_path, torch_dtype=torch.bfloat16, trust_remote_code=True)
#       6 tokenizer = AutoTokenizer.from_pretrained(model_path, trust_remote_code=True)
#       7 model = model.to("mps").eval()
#
# File ~/Documents/GPU_Labs/.venv/lib/python3.13/site-packages/transformers/models/auto/auto_factory.py:553, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     551 if has_remote_code and trust_remote_code:
#     552     class_ref = config.auto_map[cls.__name__]
# --> 553     model_class = get_class_from_dynamic_module(
#     554         class_ref, pretrained_model_name_or_path, code_revision=code_revision, **hub_kwargs, **kwargs
#     555     )
#     556     _ = hub_kwargs.pop("code_revision", None)
#     557     cls.register(config.__class__, model_class, exist_ok=True)
#
# File ~/Documents/GPU_Labs/.venv/lib/python3.13/site-packages/transformers/dynamic_module_utils.py:552, in get_class_from_dynamic_module(class_reference, pretrained_model_name_or_path, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, repo_type, code_revision, **kwargs)
#     539 # And lastly we get the class inside our newly created module
#     540 final_module = get_cached_module_file(
#     541     repo_id,
#     542     module_file + ".py",
#    (...)    550     repo_type=repo_type,
#     551 )
# --> 552 return get_class_in_module(class_name, final_module, force_reload=force_download)
#
# File ~/Documents/GPU_Labs/.venv/lib/python3.13/site-packages/transformers/dynamic_module_utils.py:249, in get_class_in_module(class_name, module_path, force_reload)
#     247 # reload in both cases, unless the module is already imported and the hash hits
#     248 if getattr(module, "__transformers_module_hash__", "") != module_hash:
# --> 249     module_spec.loader.exec_module(module)
#     250     module.__transformers_module_hash__ = module_hash
#     251 return getattr(module, class_name)
#
# File <frozen importlib._bootstrap_external>:1026, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/.cache/huggingface/modules/transformers_modules/Dream-org/Dream-v0-Instruct-7B/05334cb9faaf763692dcf9d8737c642be2b2a6ae/modeling_dream.py:36
#      31 from transformers.modeling_outputs import (
#      32     BaseModelOutput,
#      33     MaskedLMOutput,
#      34 )
#      35 from transformers.modeling_rope_utils import ROPE_INIT_FUNCTIONS
# ---> 36 from transformers.modeling_utils import PreTrainedModel
#      37 from transformers.utils import (
#      38     add_start_docstrings,
#      39     add_start_docstrings_to_model_forward,
#    (...)     42     logging,
#      43 )
#      44 from transformers import PretrainedConfig
#
# File ~/Documents/GPU_Labs/.venv/lib/python3.13/site-packages/transformers/modeling_utils.py:48
#      46 from .generation import GenerationConfig, GenerationMixin
#      47 from .integrations import PeftAdapterMixin, deepspeed_config, is_deepspeed_zero3_enabled
# ---> 48 from .loss.loss_utils import LOSS_MAPPING
#      49 from .pytorch_utils import (  # noqa: F401
#      50     Conv1D,
#      51     apply_chunking_to_forward,
#    (...)     57     prune_linear_layer,
#      58 )
#      59 from .quantizers import AutoHfQuantizer, HfQuantizer
#
# File ~/Documents/GPU_Labs/.venv/lib/python3.13/site-packages/transformers/loss/loss_utils.py:19
#      16 import torch.nn as nn
#      17 from torch.nn import BCEWithLogitsLoss, MSELoss
# ---> 19 from .loss_deformable_detr import DeformableDetrForObjectDetectionLoss, DeformableDetrForSegmentationLoss
#      20 from .loss_for_object_detection import ForObjectDetectionLoss, ForSegmentationLoss
#      21 from .loss_rt_detr import RTDetrForObjectDetectionLoss
#
# File ~/Documents/GPU_Labs/.venv/lib/python3.13/site-packages/transformers/loss/loss_deformable_detr.py:4
#       1 import torch
#       2 import torch.nn as nn
# ----> 4 from ..image_transforms import center_to_corners_format
#       5 from ..utils import is_scipy_available
#       6 from .loss_for_object_detection import (
#       7     HungarianMatcher,
#       8     ImageLoss,
#    (...)     11     sigmoid_focal_loss,
#      12 )
#
# File ~/Documents/GPU_Labs/.venv/lib/python3.13/site-packages/transformers/image_transforms.py:22
#      18 from typing import Iterable, List, Optional, Tuple, Union
#      20 import numpy as np
# ---> 22 from .image_utils import (
#      23     ChannelDimension,
#      24     ImageInput,
#      25     get_channel_dimension_axis,
#      26     get_image_size,
#      27     infer_channel_dimension_format,
#      28 )
#      29 from .utils import ExplicitEnum, TensorType, is_jax_tensor, is_tf_tensor, is_torch_tensor
#      30 from .utils.import_utils import (
#      31     is_flax_available,
#      32     is_tf_available,
#    (...)     37     requires_backends,
#      38 )
#
# File ~/Documents/GPU_Labs/.venv/lib/python3.13/site-packages/transformers/image_utils.py:58
#      55         PILImageResampling = PIL.Image
#      57     if is_torchvision_available():
# ---> 58         from torchvision.transforms import InterpolationMode
#      60         pil_torch_interpolation_mapping = {
#      61             PILImageResampling.NEAREST: InterpolationMode.NEAREST,
#      62             PILImageResampling.BOX: InterpolationMode.BOX,
#    (...)     66             PILImageResampling.LANCZOS: InterpolationMode.LANCZOS,
#      67         }
#      70 if TYPE_CHECKING:
#
# File ~/Documents/GPU_Labs/.venv/lib/python3.13/site-packages/torchvision/__init__.py:8
#       5 # Don't re-order these, we need to load the _C extension (done when importing
#       6 # .extension) before entering _meta_registrations.
#       7 from . import extension  # usort:skip  # noqa: F401
# ----> 8 from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils  # usort:skip
#      10 try:
#      11     from .version import __version__  # noqa: F401
#
# File ~/Documents/GPU_Labs/.venv/lib/python3.13/site-packages/torchvision/_meta_registrations.py:163
#     153     torch._check(
#     154         grad.dtype == rois.dtype,
#     155         lambda: (
#    (...)    158         ),
#     159     )
#     160     return grad.new_empty((batch_size, channels, height, width))
# --> 163 @torch.library.register_fake("torchvision::nms")
#     164 def meta_nms(dets, scores, iou_threshold):
#     165     torch._check(dets.dim() == 2, lambda: f"boxes should be a 2d tensor, got {dets.dim()}D")
#     166     torch._check(dets.size(1) == 4, lambda: f"boxes should have 4 elements in dimension 1, got {dets.size(1)}")
#
# File ~/Documents/GPU_Labs/.venv/lib/python3.13/site-packages/torch/library.py:828, in register_fake.<locals>.register(func)
#     826 else:
#     827     use_lib = lib
# --> 828 use_lib._register_fake(op_name, func, _stacklevel=stacklevel + 1)
#     829 return func
#
# File ~/Documents/GPU_Labs/.venv/lib/python3.13/site-packages/torch/library.py:198, in Library._register_fake(self, op_name, fn, _stacklevel)
#     195 else:
#     196     func_to_register = fn
# --> 198 handle = entry.fake_impl.register(func_to_register, source)
#     199 self._registration_handles.append(handle)
#
# File ~/Documents/GPU_Labs/.venv/lib/python3.13/site-packages/torch/_library/fake_impl.py:31, in FakeImplHolder.register(self, func, source)
#      25 if self.kernel is not None:
#      26     raise RuntimeError(
#      27         f"register_fake(...): the operator {self.qualname} "
#      28         f"already has an fake impl registered at "
#      29         f"{self.kernel.source}."
#      30     )
# ---> 31 if torch._C._dispatch_has_kernel_for_dispatch_key(self.qualname, "Meta"):
#      32     raise RuntimeError(
#      33         f"register_fake(...): the operator {self.qualname} "
#      34         f"already has an DispatchKey::Meta implementation via a "
#    (...)     37         f"register_fake."
#      38     )
#      40 if torch._C._dispatch_has_kernel_for_dispatch_key(
#      41     self.qualname, "CompositeImplicitAutograd"
#      42 ):
#
# RuntimeError: operator torchvision::nms does not exist
